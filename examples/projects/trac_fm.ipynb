# %%
import pandas as pd

# %%
df = pd.read_csv('trac_fm_output.csv')
df.head(10)
# Out:
#          filename language                                      transcription  \
# 0    MEGA 9.2.mp3      ach  ki nyiŋ gilwaŋa ni lakot monika abedo ocuda i ...
# 1    MEGA 9.3.mp3      ach  a nyiŋa gilwon onen abedo obiya pien muweko ny...
# 2   MEGA 12.1.mp3      ach  an nye aneno gladic abedo i limo aneno waye li...
# 3   MEGA 12.3.mp3      ach  anya amony jenifa abedo lacor yo mu aramo kony...
# 4    MEGA 9.1.mp3      ach  aniowu magrec bede i kek gwana gin wumiyo atin...
# 5   MEGA 12.2.mp3      ach  nyia florence leonat ga aul tok toa laik maido...
# 6  SIMBA 10.4.mp3      lug  jajjawo abaana nga ndimatugga naye abaana kati...
# 7  SIMBA 10.1.mp3      lug  ensowooza yange ku baana bano abato abataninet...
# 8  SIMBA 10.3.mp3      lug  amanyi abampita dauda twaha ndawula nera ampan...
# 9  SIMBA 10.2.mp3      lug  akigezesawo wano ematugga kyenkugamba kiri kim...
#
#                                          translation
# 0  my name is monika and I was stranded in the vi...
# ...
